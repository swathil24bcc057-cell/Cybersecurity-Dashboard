# %%
import pandas as pd

# %%
from google.colab import files
dp=files.upload()
# Out:
#      <input type="file" id="files-9d665ce4-eef9-45cf-bb83-11c9074aee7d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9d665ce4-eef9-45cf-bb83-11c9074aee7d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_excel(r"projectdata.xlsx")

# %%
data
# Out:
#         num_words  num_unique_words  num_stopwords  num_links  \
# 0             140                94             52          0
# 1               5                 5              1          0
# 2              34                32             15          0
# 3               6                 6              2          0
# 4               9                 9              2          0
# ...           ...               ...            ...        ...
# 524841        782               327            301          2
# 524842         36                30             11          0
# 524843         61                46             11          0
# 524844        213               136             89          0
# 524845         26                24              3          0
#
#         num_unique_domains  num_email_addresses  num_spelling_errors  \
# 0                        0                    0                    0
# 1                        0                    0                    0
# ...

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#         num_words  num_unique_words  num_stopwords  num_links  \
# 0             140                94             52          0
# 1               5                 5              1          0
# 2              34                32             15          0
# 3               6                 6              2          0
# 4               9                 9              2          0
# ...           ...               ...            ...        ...
# 524841        782               327            301          2
# 524842         36                30             11          0
# 524843         61                46             11          0
# 524844        213               136             89          0
# 524845         26                24              3          0
#
#         num_unique_domains  num_email_addresses  num_spelling_errors  \
# 0                        0                    0                    0
# 1                        0                    0                    0
# ...

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 524841    False
# 524842    False
# 524843     True
# 524844    False
# 524845     True
# Length: 524846, dtype: bool

# %%
df.drop_duplicates()
# Out:
#         num_words  num_unique_words  num_stopwords  num_links  \
# 0             140                94             52          0
# 1               5                 5              1          0
# 2              34                32             15          0
# 3               6                 6              2          0
# 4               9                 9              2          0
# ...           ...               ...            ...        ...
# 524839         98                71             39          0
# 524840         65                52             22          2
# 524841        782               327            301          2
# 524842         36                30             11          0
# 524844        213               136             89          0
#
#         num_unique_domains  num_email_addresses  num_spelling_errors  \
# 0                        0                    0                    0
# 1                        0                    0                    0
# ...

# %%
df
# Out:
#         num_words  num_unique_words  num_stopwords  num_links  \
# 0             140                94             52          0
# 1               5                 5              1          0
# 2              34                32             15          0
# 3               6                 6              2          0
# 4               9                 9              2          0
# ...           ...               ...            ...        ...
# 524841        782               327            301          2
# 524842         36                30             11          0
# 524843         61                46             11          0
# 524844        213               136             89          0
# 524845         26                24              3          0
#
#         num_unique_domains  num_email_addresses  num_spelling_errors  \
# 0                        0                    0                    0
# 1                        0                    0                    0
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#         num_words  num_unique_words  num_stopwords  num_links  \
# 0             140                94             52          0
# 1               5                 5              1          0
# 2              34                32             15          0
# 3               6                 6              2          0
# 4               9                 9              2          0
# ...           ...               ...            ...        ...
# 524839         98                71             39          0
# 524840         65                52             22          2
# 524841        782               327            301          2
# 524842         36                30             11          0
# 524844        213               136             89          0
#
#         num_unique_domains  num_email_addresses  num_spelling_errors  \
# 0                        0                    0                    0
# 1                        0                    0                    0
# ...

# %%
df.dropna()
# Out:
#         num_words  num_unique_words  num_stopwords  num_links  \
# 0             140                94             52          0
# 1               5                 5              1          0
# 2              34                32             15          0
# 3               6                 6              2          0
# 4               9                 9              2          0
# ...           ...               ...            ...        ...
# 524839         98                71             39          0
# 524840         65                52             22          2
# 524841        782               327            301          2
# 524842         36                30             11          0
# 524844        213               136             89          0
#
#         num_unique_domains  num_email_addresses  num_spelling_errors  \
# 0                        0                    0                    0
# 1                        0                    0                    0
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel("projectdata.xlsx")

plt.subplot(2,2,1)
plt.plot(df['num_words'], df['num_unique_words'], color='blue')
plt.xlabel("num_words")
plt.ylabel("num_unique_words")

plt.subplot(2,2,2)
plt.pie(df['num_unique_words'][:5], labels=df['num_words'][:5])

plt.subplot(2,2,3)
plt.bar(df['num_words'][:10], df['num_unique_words'][:10], color='blue')
plt.xlabel("num_words")
plt.ylabel("num_unique_words")

plt.subplot(2,2,4)
plt.scatter(df['num_words'], df['num_unique_words'], color='blue')
plt.xlabel("num_words")
plt.ylabel("num_unique_words")

plt.tight_layout()
plt.savefig("dashboard.png",dpi=300,bbox_inches='tight')
plt.show()
